# %%
name="Nick Adams"
age = 35
profession = 'programmer'

print(f'this is {name} who is a {profession} and {age}')
# Out:
# this is Nick Adams who is a programmer and 35

# %%
yes=334456
no=300223
percentage=yes/(yes+no)
print(percentage)
print('{:-3} YES votes {:2.2%}'.format(yes,percentage))
# Out:
# 0.5269687511324622
# 334456 YES votes 52.70%

# %%
s="hello world"
print(s)
str(s)
repr(s)
# Out:
# hello world
# "'hello world'"

# %%
s="hello world\n"
repr(s)
# Out:
# "'hello world\\n'"

# %%
import math

print(f"the value of pi is approximately {math.pi : .4f} ")
# Out:
# the value of pi is approximately  3.1416

# %%
table={'nick':1234,'jack':4545,'adam':9988}

for name,phone in table.items():
    print(f"{name:10} ==> {phone:10d}")
# Out:
# nick       ==>       1234
# jack       ==>       4545
# adam       ==>       9988

# %%
a="holola"
print(f"the value of a is : {a!r}")
# Out:
# the value of a is : 'holola'

# %%
print("my name is {} and i am a professional {}.".format("nick","AI developer"))
# Out:
# my name is nick and i am a professional AI developer.

# %%
print('{0} and {1}'.format('nm','seed'))
# Out:
# nm and seed

# %%
print('{1} and {0}'.format('seed','nm'))
# Out:
# nm and seed

# %%
print('this food is {food} and the taste is {taste}'.format(food="burger",taste='delicious'))
# Out:
# this food is burger and the taste is delicious

# %%
print('the first person : {0} and the second one : {1} is going to {place}'.format('nick','adam',place='dhaka'))
# Out:
# the first person : nick and the second one : adam is going to dhaka

# %%
table={'nm':4444,'adam':6453,'nick':9999}

print('nm= {0[nm]:d}; adam= {0[nick]:d}; nicky= {0[adam]:d} '.format(table))
# Out:
# nm= 4444; adam= 9999;nicky= 6453

# %%
table={'nm':4444,'adam':6453,'nick':9999}

print('nm= {nm:d}; adam= {nick:d}; nicky= {adam:d} '.format(**table))
# Out:
# nm= 4444; adam= 9999; nicky= 6453

# %%
for i in range(1,11):
    print('{0:2d}  {1:3d}  {2:4d}'.format(i, i*i, i*i*i))
# Out:
#  1    1     1
#  2    4     8
#  3    9    27
#  4   16    64
#  5   25   125
#  6   36   216
#  7   49   343
#  8   64   512
#  9   81   729
# 10  100  1000

# %%
'20'.zfill(4)
# Out:
# '0020'

# %%
'3.1426788'.zfill(10)
# Out:
# '03.1426788'

# %%
'3.23234567'.zfill(5)
# Out:
# '3.23234567'

# %%
import math
print('the value of pie is approximately %2.7f' %math.pi)
# Out:
# the value of pie is approximately 3.1415927

# %%
f =open("python_basics.ipynb",'r')
print(f)
# Out:
# <_io.TextIOWrapper name='python_basics.ipynb' mode='r' encoding='cp1252'>

# %% [markdown]
# The first argument is a string containing the filename. The second argument is another string containing a few characters describing the way in which the file will be used. mode can be 'r' when the file will only be read, 'w' for only writing (an existing file with the same name will be erased), and 'a' opens the file for appending; any data written to the file is automatically added to the end. 'r+' opens the file for both reading and writing. The mode argument is optional; 'r' will be assumed if it’s omitted.

# %%
with open('python_basics.ipynb') as f:
    read_data= f.read()
    print(read_data)
f.close()
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 1,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "Hello rainbow python codes\n"
#      ]
#     }
#    ],
#    "source": [
#     "print(\"Hello rainbow python codes\")"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 9,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "4\n",
#       "0\n",
#       "4\n",
#       "1.5\n",
#       "1\n",
#       "0\n",
#       "25\n"
#      ]
#     }
#    ],
#    "source": [
#     "print(2+2)\n",
#     "print(2-2)\n",
#     "print(2*2)\n",
#     "print(3/2)\n",
#     "print(2//2)\n",
#     "print(9%3)\n",
#     "print(5**2)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 25,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
# ...

# %%
import os

dir(os)
# Out:
# ['DirEntry',
#  'F_OK',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_putenv',
#  '_unsetenv',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
#  'dup2',
#  'environ',
#  'error',
#  'execl',
#  'execle',
#  'execlp',
# ...

# %%
print('hello')
# Out:
# hello
